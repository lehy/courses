# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append('..')
import ronan
import matplotlib.pyplot as plt

# %%
x = 'iteration'
components = ['accuracy']
fig, axes = plt.subplots(2, figsize=(14, 12))

for ax, x in zip(axes, ['iteration', 'elapsed_time']):
    ax = [ax]
    ronan.plot_logs(['resnet50-res5-batch128-multiprocess'], axes=ax, x=x, components=components)
    ronan.plot_logs(['resnet50-res5-batch128-multiprocess-1M'], axes=ax, x=x, components=components)
    ronan.plot_logs(['ResNet50-res5-1M-batch128'], axes=ax, x=x, components=components)
axes[0].legend()

# %%
149 * 128
# Out:
# 19072

# %%
1000000/128.
# Out:
# 7812.5
