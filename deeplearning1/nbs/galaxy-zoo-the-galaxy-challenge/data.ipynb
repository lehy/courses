# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import ronan
import pandas as pd

# %%
datasets = ronan.load_galaxy_datasets()

# %%
for i in range(5):
    ronan.plot_dataset_image(datasets.train[i])

# %%
for i in range(5):
    ronan.plot_dataset_image(datasets.test[i])

# %%
for i in range(5):
    ronan.plot_dataset_image(datasets.validation[i])

# %%
# Our target MSE for placing #163 (out of 326 entries)
0.13328**2
# Out:
# 0.017763558400000004
