# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append('..')
import ronan

# %%
data = ronan.load_painting_datasets()
# Out:
# DEBUG:ronan:building labeled pairs dataset
# DEBUG:ronan:labeled pairs dataset: len 1000544
# DEBUG:ronan:building train, validation split
# DEBUG:ronan:building unlabeled image pair dataset
# DEBUG:ronan:done building dataset

# %%
#size_prediction = 2
#net = ronan.ResNet50(output_size=size_prediction, finetune_from_layer='fc6')
#ronan.train(net, data, 'resnet50-fc6-batch128',
#            train_batch_size=128)
# Out:
# DEBUG:ronan:setting up optimizer
# DEBUG:ronan:creating trainer
# DEBUG:ronan:running training loop
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 3.46758       0           1           0.492188                                 0.860338
# 5.22706       0           2           0.507812                                 0.784814
# 6.99095       0           3           0.476562                                 0.813908
# 8.76868       0           4           0.578125                                 0.699194
# 10.5168       0           5           0.554688                                 0.727741
# 12.2801       0           6           0.484375                                 0.845828
# 14.0541       0           7           0.53125                                  0.786374
# 15.8274       0           8           0.570312                                 0.709089
# ...

# %%
#size_prediction = 2
#net = ronan.ResNet50(output_size=size_prediction, finetune_from_layer='res5')
#ronan.train(net, data, 'resnet50-res5-batch128',
#            train_batch_size=128)
# Out:
# DEBUG:ronan:setting up optimizer
# DEBUG:ronan:creating trainer
# DEBUG:ronan:running training loop
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 2.20265       0           1           0.484375                                 0.990235
# 4.31803       0           2           0.539062                                 1.12486
# 6.46676       0           3           0.523438                                 1.05198
# 8.59925       0           4           0.570312                                 0.921217
# 10.7325       0           5           0.5625                                   1.06544
# 12.8702       0           6           0.570312                                 1.32858
# 15.0133       0           7           0.492188                                 1.40446
# 17.1477       0           8           0.59375                                  0.922108
# ...

# %%
size_prediction = 2
net = ronan.ResNet50(output_size=size_prediction, finetune_from_layer='res5')
ronan.train(net, data, 'resnet50-res5-batch128-multiprocess',
            train_batch_size=128)
# Out:
# DEBUG:ronan:setting up optimizer
# DEBUG:ronan:creating trainer
# DEBUG:ronan:running training loop
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 2.50567       0           1           0.429688                                 0.833435
# 3.90024       0           2           0.453125                                 1.12761
# 5.2812        0           3           0.554688                                 0.953331
# 6.72657       0           4           0.632812                                 0.846581
# 8.11923       0           5           0.515625                                 0.924213
# 9.51919       0           6           0.640625                                 0.911906
# 10.9183       0           7           0.617188                                 0.849837
# 12.3753       0           8           0.570312                                 1.04873
# ...

# %%
# data = ronan.load_painting_datasets()
size_prediction = 2
net = ronan.ResNet50(output_size=size_prediction, finetune_from_layer='res5')
ronan.train(net, data, 'res5-1M',
            train_batch_size=128, trigger_save_trainer=(500, 'iteration'))
# Out:
# DEBUG:ronan:setting up optimizer
# DEBUG:ronan:creating trainer
# INFO:ronan:full model name: ResNet50-res5-1M-batch128
# DEBUG:ronan:running training loop
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 2.50936       0           1           0.46875                                  0.810388
# 3.93501       0           2           0.59375                                  0.895849
# 5.31452       0           3           0.570312                                 0.881284
# 14.2332       0           4           0.539062       0.515625                  1.07321     2.23883
# 21.664        0           5           0.554688                                 0.997971
# 23.0521       0           6           0.515625                                 0.911805
# 24.425        0           7           0.578125                                 0.949072
# ...
