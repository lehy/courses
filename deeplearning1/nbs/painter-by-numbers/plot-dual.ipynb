# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append('..')
import ronan
import matplotlib.pyplot as plt

# %%
x = 'iteration'
components = ['accuracy']
fig, axes = plt.subplots(2, figsize=(14, 12))

for ax, x in zip(axes, ['iteration', 'elapsed_time']):
    ax = [ax]
    ronan.plot_logs(['ResNet50-res5-1M-batch128'], axes=ax, x=x, components=components)
    ronan.plot_logs(['DualNet-1M-batch128'], axes=ax, x=x, components=components)
    ronan.plot_logs(['DualNet-1M-ores5-fres1-batch128'], axes=ax, x=x, components=components)
axes[0].legend()
