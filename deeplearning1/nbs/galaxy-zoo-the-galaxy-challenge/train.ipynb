# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import ronan
import chainer

# %%
datasets = ronan.load_galaxy_datasets()

# %%
size_prediction = len(datasets.train[0][1])
# net = ronan.ResNet50(output_size=size_prediction)

# %%
net = ronan.ResNet50(output_size=size_prediction)
ronan.train(net, datasets, 'batch128',
            loss_fun=chainer.functions.mean_squared_error, accuracy_fun=chainer.functions.mean_absolute_error,
            train_batch_size=128)
# Out:
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 1.94291       0           1           0.498277                                 0.400725
# 3.37707       0           2           0.534956                                 0.43111
# 4.80139       0           3           0.444879                                 0.312072
# 6.22717       0           4           0.417166                                 0.284248
# 7.65375       0           5           0.428771                                 0.288185
# 9.07499       0           6           0.400214                                 0.254736
# 10.5015       0           7           0.3558                                   0.201483
# 11.9237       0           8           0.350571                                 0.198847
# 13.3557       0           9           0.356061                                 0.206008
# ...

# %%
net = ronan.ResNet50(output_size=size_prediction)
ronan.train(net, datasets, 'batch256',
            loss_fun=chainer.functions.mean_squared_error,
            accuracy_fun=chainer.functions.mean_absolute_error, train_batch_size=256)
# Out:
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 4.95288       0           2           0.491516                                 0.383625
# 10.1343       0           4           0.426725                                 0.29426
# 15.3039       0           6           0.410462                                 0.267141
# 20.472        0           8           0.357307                                 0.205456
# 25.6036       0           10          0.366928                                 0.213079
# 30.6941       0           12          0.329149                                 0.174555
# 35.8188       0           14          0.322923                                 0.169473
# 40.9714       0           16          0.316891                                 0.163405
# 46.1721       0           18          0.297404                                 0.144375
# ...

# %%
net = ronan.ResNet50(output_size=size_prediction)
ronan.train(net, datasets, 'batch64',
            loss_fun=chainer.functions.mean_squared_error,
            accuracy_fun=chainer.functions.mean_absolute_error, train_batch_size=64)
# Out:
# elapsed_time  epoch       iteration   main/accuracy  validation/main/accuracy  main/loss   validation/main/loss
# 1.35291       0           2           0.494074                                 0.376658
# 2.98287       0           4           0.425961                                 0.290043
# 5.76473       0           6           0.3946                                   0.24488
# 7.41737       0           8           0.365263                                 0.213263
# 9.03401       0           10          0.35776                                  0.201909
# 10.667        0           12          0.33653                                  0.178739
# 12.2822       0           14          0.320606                                 0.167195
# 13.9351       0           16          0.321021                                 0.166555
# 15.7371       0           18          0.305836                                 0.1482
# ...
