# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import ronan

# %%
fig, axes = plt.subplots(1, sharex=True, figsize=(14, 8))
if not isinstance(axes, list):
    axes = [axes]
components = ['loss']
ronan.plot_logs(['batch64'], axes, components=components)
#ronan.plot_logs(['batch128'], axes, components=components) # this was overwritten by res5-batch128 :(
ronan.plot_logs(['batch256'], axes, components=components)
axes[0].axhline(0.13328**2, label="target")
axes[0].set_ylim((0, 0.05))
axes[0].legend()
# Out:
# measurement not found: validation/main/loss

# %%
import numpy as np
np.sqrt(0.025)
# Out:
# 0.15811388300841897

# %%
0.13328**2
# Out:
# 0.017763558400000004

# %%
fig, axes = plt.subplots(1, sharex=True, figsize=(14, 8))
if not isinstance(axes, list):
    axes = [axes]
components = ['loss']
ronan.plot_logs(['batch64'], axes, components=components)
ronan.plot_logs(['res5-batch128'], axes, components=components)
ronan.plot_logs(['batch256'], axes, components=components)
axes[0].axhline(0.13328**2, label="target")
axes[0].set_ylim((0, 0.05))
axes[0].legend()
# Out:
# measurement not found: validation/main/loss

# %%
fig, axes = plt.subplots(1, sharex=True, figsize=(14, 8))
if not isinstance(axes, list):
    axes = [axes]
components = ['loss']
ronan.plot_logs(['res5-batch128'], axes, components=components, x='iteration')
axes[0].axhline(0.13328**2, label="target")
axes[0].set_ylim((0, 0.05))
axes[0].legend()
